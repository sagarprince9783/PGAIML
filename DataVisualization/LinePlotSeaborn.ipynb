# %% [markdown]
# # Seaborn

# %% [markdown]
# Seaborn is a data visualization library built on top pf matplotlib and closely integrated with pandas data structures in python

# %% [markdown]
# # Seaborn Graphas

# %% [markdown]
# a) Scatter Graph
# b) Customizing with Matplotlib
# c) Box plot
# d) Violin plot
# e) Swarm Plot
# f) Heatmap
# g) Histogram
# h) Bar Plot
# i) Factor Plot
# j) Density Plot
# k) Joint Distribution plot

# %% [markdown]
# # Dependency of Seaborn

# %% [markdown]
# 1) Numpy
# 2) Matplotlib
# 3) Scipy
# 4) Pandas

# %% [markdown]
# # Line Plot in Searborn

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
var=[1,2,3,4,5,6,7]
var_1=[2,3,4,1,5,6,7]

# %%
plt.plot(var,var_1)
plt.show()

# %%
sns.lineplot(x=var,y=var_1)
plt.show()

# %%
x_1=pd.DataFrame({"var":var,"var_1":var_1})
sns.lineplot(x='var',y='var_1',data=x_1)
plt.show()

# %%
y_1=sns.load_dataset('penguins')

# %%
y_1.head(2)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female

# %%
# hue properties use to draw a graph for any specific column basis like column sex 
# palette is used to change the color
sns.lineplot(x='bill_length_mm',y='flipper_length_mm',data=y_1,hue='sex',style='sex',palette='Accent',markers=['<','o'],dashes=False)
plt.show()
